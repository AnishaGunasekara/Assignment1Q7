# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
im_og = cv.imread('/content/drive/MyDrive/Image_Processing/lor.png')
im_og = cv.cvtColor(im_og, cv.COLOR_BGR2RGB)

def im_z(im_og, zoom_factor):
    if zoom_factor <= 0 or zoom_factor > 10:
        raise ValueError("Zoom factor must be in the range (0, 10]")

    height, width, channels = im_og.shape

    new_height = int(height * zoom_factor)
    new_width = int(width * zoom_factor)

    im_z = cv.resize(im_og, (new_width, new_height), interpolation=cv.INTER_NEAREST)

    return im_z

zoom_factor = 5.0
im_z = im_z(im_og, zoom_factor)

fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(im_og, cmap='gray')
ax[0].set_title('Original')
ax[1].imshow(im_z, cmap= 'gray')
ax[1].set_title('Zoomed Output Using Nearest-Neighbour Interpolation')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Text(0.5, 1.0, 'Zoomed Output Using Nearest-Neighbour Interpolation')

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
im_og = cv.imread('/content/drive/MyDrive/Image_Processing/lor.png')
im_og = cv.cvtColor(im_og, cv.COLOR_BGR2RGB)

print(f"im_og.shape: {im_og.shape}")
print(f"scaled_image.shape: {scaled_image.shape}")

def scale_up_image(im_og, scale_factor):
    new_height = int(im_og.shape[0] * scale_factor)
    new_width = int(im_og.shape[1] * scale_factor)
    scaled_image = cv2.resize(im_og, (new_width, new_height), interpolation=cv2.INTER_LINEAR)
    return scaled_image

def calculate_normalized_ssd(im_og, scaled_image):
    ssd = np.sum((im_og.astype(np.float32) - scaled_image.astype(np.float32))**2)
    normalized_ssd = ssd / float(im_og.size)
    return normalized_ssd


# Check if the image is loaded successfully
if im_og is None:
    print("Error: Could not load the original image.")
else:
    # Scale up the image by a factor of 4
    scale_factor = 4
    scaled_image = scale_up_image(im_og, scale_factor)

    im_og_resized = cv2.resize(im_og, (scaled_image.shape[1], scaled_image.shape[0]))


fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(im_og, cmap='gray')
ax[0].set_title('Original')
ax[1].imshow(im_og_resized, cmap= 'gray')
ax[1].set_title('Scaled image')

plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# im_og.shape: (1080, 1920, 3)
# scaled_image.shape: (4320, 7680, 3)

# %%
import cv2
import numpy as np
from google.colab import drive
from google.colab.patches import cv2_imshow

drive.mount('/content/drive')
im_og = cv2.imread('/content/drive/MyDrive/Image_Processing/lor.png')
im_og = cv2.cvtColor(im_og, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB

def zoom_image(original_image, zoom_factor):
    if zoom_factor <= 0 or zoom_factor > 10:
        raise ValueError("Zoom factor must be in the range (0, 10]")

    height, width, channels = original_image.shape

    new_height = int(height * zoom_factor)
    new_width = int(width * zoom_factor)

    zoomed_image = cv2.resize(original_image, (new_width, new_height), interpolation=cv2.INTER_LINEAR)

    return zoomed_image

zoom_factor = 5.0
zoomed_image = zoom_image(im_og, zoom_factor)

# Display the original and zoomed images
cv2_imshow(im_og)
cv2_imshow(zoomed_image)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
im_og = cv.imread('/content/drive/MyDrive/Image_Processing/lor.png')
im_og = cv.cvtColor(im_og, cv.COLOR_BGR2RGB)

def im_z(im_og, zoom_factor):
    if zoom_factor <= 0 or zoom_factor > 10:
        raise ValueError("Zoom factor must be in the range (0, 10]")

    height, width, channels = im_og.shape

    new_height = int(height * zoom_factor)
    new_width = int(width * zoom_factor)

    im_z = cv.resize(im_og, (new_width, new_height), interpolation=cv.INTER_LINEAR)

    return im_z

zoom_factor = 5.0
im_z = im_z(im_og, zoom_factor)

fig, ax = plt.subplots(1, 2, figsize=(10, 10))
ax[0].imshow(im_og, cmap='gray')
ax[0].set_title('Original')
ax[1].imshow(im_z, cmap= 'gray')
ax[1].set_title('Zoomed Output Using Bilinear Interpolation')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Text(0.5, 1.0, 'Zoomed Output Using Bilinear Interpolation')
